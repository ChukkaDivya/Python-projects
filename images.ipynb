# %%
from PIL import Image

# %%
mac=Image.open("image.jpg")

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x406>

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac.size
# Out:
# (612, 406)

# %%
mac.filename
# Out:
# 'image.jpg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
mac.crop((100,100,300,300))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
pencils=Image.open("pencils.jpg")

# %%
pencils
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1300x951>

# %%
pencils.size
# Out:
# (1300, 951)

# %%
pencils.crop((0,750,1350/3,860))
# Out:
# <PIL.Image.Image image mode=RGB size=450x110>

# %%
p=pencils.crop((0,750,1350/3,860))

# %%
p.show()

# %%
mac.paste(im=p,box=(0,0))

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x406>

# %%
mac.resize((500,500))
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
mac.rotate(360)
# Out:
# <PIL.Image.Image image mode=RGB size=612x406>

# %%
red=Image.open("red_color.jpg")

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200>

# %%
red.putalpha(128)

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200>

# %%
blue=Image.open("blue_color.png")

# %%
words=Image.open("word_matrix.jpg")

# %%
mask=Image.open("mask.jpg")

# %%
words.size
# Out:
# (1015, 559)

# %%
mask=mask.resize((1015,559))

# %%
mask.putalpha(200)

# %%
words.paste(im=mask,box=(0,0),mask=mask)

# %%
words
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1015x559>
