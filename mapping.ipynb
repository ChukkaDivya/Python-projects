# %%
def my_square(num):
    return num**2

# %%
my_num=[1,2,3,4,5]
for i in my_num:
    print(my_square(i))
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
for i in map(my_square,my_num)
# Out:
# (1, 4, 9, 16, 25)

# %%
list(map(my_square,my_num))
# Out:
# [1, 4, 9, 16, 25]

# %%
# Define a function to double a number
def double(x):
    return x * 2

# Create a list of numbers
numbers = [1, 2, 3, 4, 5]

# Use map() to double each number in the list
doubled_numbers = map(double, numbers)
type(doubled_numbers)
# Out:
# map

# %%
def check_even(n):
    return n%2==0

# %%
for i in map(check_even,my_num):
    print(i)
# Out:
# False
# True
# False
# True
# False
