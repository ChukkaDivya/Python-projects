# %%
pwd
# Out:
# 'C:\\dpython'

# %%
f=open("practice.txt",'w+')
f.write("Hey ! This is a practice file see ya ")
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\dpython'

# %%
os.listdir('C:\\users\\admin')
# Out:
# ['.android',
#  '.appletviewer',
#  '.cache',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.eclipse',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.p2',
#  '.spyder-py3',
#  '.vscode',
#  '3 cup motee.ipynb',
#  '3D Objects',
#  '576',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'd4ac4633ebd6440fa397b84f1bc94a3c.7z',
#  'Desktop',
#  'dictionary.ipynb',
#  'dictionary2.ipynb',
#  'Documents',
#  'Downloads',
#  'eclipse',
#  'eclipse-workspace',
#  'errorhw.ipynb',
#  'errors.ipynb',
#  'extpractice.py',
#  'Favorites',
#  'files.ipynb',
#  'files2.ipynb',
#  'firstp.py',
#  'functionsassign.ipynb',
#  'generatorhw.ipynb',
#  'generators.ipynb',
#  'geomentry.py',
#  'hello.txt',
#  'ifelseassign.ipynb',
#  'inittk.ini',
#  'inst.ini',
#  'IntelGraphicsProfiles',
#  'Links',
#  'List.ipynb',
#  'Local Settings',
#  'mapping.ipynb',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
# ...

# %%
import shutil

# %%
os.listdir('C:\\divyeah')
# Out:
# ['practice.txt']

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'collection module part2.ipynb',
#  'practice.txt',
#  'Untitled.ipynb']

# %%
send2trash.send2trash('practice.txt')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'collection module part2.ipynb', 'Untitled.ipynb']

# %%
filepath='C:\\divyeah'

# %%
for folder,subfolder,file in os.walk(filepath):
    print(f'in folder{folder}')
    for i in subfolder:
        print(f'sub foldder is {i}')
    for j in file:
        print(f'files {f}')
# Out:
# in folderC:\divyeah
# sub foldder is subfolder
# files <_io.TextIOWrapper name='practice.txt' mode='w+' encoding='cp1252'>
# in folderC:\divyeah\subfolder
# files <_io.TextIOWrapper name='practice.txt' mode='w+' encoding='cp1252'>
