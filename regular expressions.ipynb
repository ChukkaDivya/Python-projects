# %%
text="The agent's phone number is 408-555-1234. Call soon!"

# %%
'phone' in text
# Out:
# True

# %%
import re

# %%
pattern='phone'

# %%
re.search(pattern,text)
# Out:
# <re.Match object; span=(12, 17), match='phone'>

# %%
not_pattern='how'

# %%
re.search(not_pattern,text)

# %%
match1=re.search(pattern,text)

# %%
type(match1)
# Out:
# re.Match

# %%
print(match1)
# Out:
# <re.Match object; span=(12, 17), match='phone'>

# %%
match1.span()
# Out:
# (12, 17)

# %%
match1.start()
# Out:
# 12

# %%
match1.end()
# Out:
# 17

# %%
text1="my phone once,my phone twice"

# %%
pattern2='phone'

# %%
match=re.search(pattern2,text1)

# %%
match
# Out:
# <re.Match object; span=(3, 8), match='phone'>

# %%
matches=re.findall('phone',text1)

# %%
matches
# Out:
# ['phone', 'phone']

# %%
type(matches)
# Out:
# list

# %%
len(matches)
# Out:
# 2

# %%
for match in re.finditer('phone',text1):
    print(match.group())
# Out:
# phone
# phone

# %%
#part2

# %%
text='my phone number is 408-555-1234'

# %%
phone=re.search(r'\d\d\d-\d\d\d-\d\d\d\d',text)

# %%
phone
# Out:
# <re.Match object; span=(19, 31), match='408-555-1234'>

# %%
phone=re.search(r'\d{3}-\d{3}-\d{4}',text)

# %%
phone
# Out:
# <re.Match object; span=(19, 31), match='408-555-1234'>

# %%
phone_pattern=re.compile(r'(\d{3})-(\d{3})-(\d{4})')

# %%
results=re.search(phone_pattern,text)

# %%
results.group(1)
# Out:
# '408'

# %%
re.search('cat|dog','The cat is here')
# Out:
# <re.Match object; span=(4, 7), match='cat'>

# %%
re.findall(r'...at','the cat sat on a mat went splat')
# Out:
# ['e cat', 'a mat', 'splat']

# %%
re.findall(r'^\d','2 is a number')
# Out:
# ['2']

# %%
re.findall(r'^\d',' the 2 is a number')
# Out:
# []

# %%
re.findall(r'\d$','number is 2 bye')
# Out:
# []

# %%
re.findall(r'[^\d]+','there are 5 no.s inside ')
# Out:
# ['there are ', ' no.s inside ', ' sentences']

# %%
a=re.findall(r'[^?!]+','hey there !,How are you doing?')

# %%
a
# Out:
# ['hey there ', ',How are you doing']

# %%
''.join(a)
# Out:
# 'hey there ,How are you doing'
